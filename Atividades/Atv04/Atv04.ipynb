// %% [markdown]
// # Exercício 01
// <p style="text-align:justify;">
// Crie um programa que armazene um vetor com as notas de dez alunos, calcule e imprima a média dessas notas e depois informe a quantidade de notas acima e abaixo da média calculada.
// </p>

// %%
import java.util.Scanner;

Scanner entrada = new Scanner(System.in);

double[] notas = new double[10];
double soma = 0;
int acima = 0;
int abaixo = 0;
double media = 0;

for (int i = 0; i < notas.length; i++) {
    System.out.printf("Nota aluno %d: ", (i + 1));
    notas[i] = entrada.nextDouble();
    soma += notas[i];
}

media = soma / notas.length;

for (int i = 0; i < notas.length; i++) {

    if (notas[i] > media) {
        acima++;
    } else if (notas[i]  < media) {
        abaixo++;
    }
}

System.out.println("Média:");
System.out.printf("%.2f\n", media);
System.out.println("Notas acima da média:");
System.out.println(acima);
System.out.println("Notas abaixo da média:");
System.out.println(abaixo);

entrada.close();
// Out:
// Nota aluno 1:
//  8
// Nota aluno 2:
//  9
// Nota aluno 3:
//  10
// Nota aluno 4:
//  4
// Nota aluno 5:
//  3
// Nota aluno 6:
//  10
// Nota aluno 7:
//  7
// Nota aluno 8:
//  6
// Nota aluno 9:
//  1
// Nota aluno 10:
//  10
// Média:
// 6.80
// Notas acima da média:
// 6
// Notas abaixo da média:
// 4
// null

// %% [markdown]
// # Exercício 02
// <p style="text-align:justify;">
// Construa uma classe em Java que seja capaz de efetuar a leitura de uma matriz de valores reais de tamanho 3 x 3, calculando seu determinante.
// </p>

// %%
import java.util.Scanner;

Scanner entrada = new Scanner(System.in);

double[][] matriz = new double[3][3];

System.out.println("Digite os elementos da matriz 3x3:");

for (int i = 0; i < 3; i++) {
    for (int j = 0; j < 3; j++) {
        System.out.printf("Elemento [%d][%d]: ", i, j);
        matriz[i][j] = entrada.nextDouble();
    }
}

double determinante = matriz[0][0] * (matriz[1][1] * matriz[2][2] - matriz[1][2] * matriz[2][1]) - matriz[0][1] * (matriz[1][0] * matriz[2][2] - matriz[1][2] * matriz[2][0]) + matriz[0][2] * (matriz[1][0] * matriz[2][1] - matriz[1][1] * matriz[2][0]);

System.out.println("O determinante da matriz é: " + determinante);

entrada.close();
// Out:
// Digite os elementos da matriz 3x3:
// Elemento [0][0]:
//  1
// Elemento [0][1]:
//  2
// Elemento [0][2]:
//  3
// Elemento [1][0]:
//  4
// Elemento [1][1]:
//  5
// Elemento [1][2]:
//  6
// Elemento [2][0]:
//  7
// Elemento [2][1]:
//  8
// Elemento [2][2]:
//  1
// O determinante da matriz é: 24.0
// null

// %% [markdown]
// # Exercício 03
// <p style="text-align:justify;">
// Faça uma classe contendo dois arrays do tipo inteiro, um chamado par e outro chamado ímpar. Cada array deve conter 10 elementos. A seguir, faça um laço de repetição com 10 iterações e que contenha internamente a geração randômica de números entre 1 e 20. Se o valor gerado for par, armazene no array chamado par, caso contrário, no array chamado impar. Ao final, apresente o conteúdo de cada um dos arrays.
// </p>

// %%
import java.util.Random;

Random random = new Random();
int[] par = new int[10];
int[] impar = new int[10];

for (int i = 0; i < 10; i++) {
    int numero = random.nextInt(21);

    if (numero % 2 == 0) {
        par[i] = numero;
    } else {
        impar[i] = numero;
    }
}

System.out.println("Números Pares:");
for (int i = 0; i < par.length; i++) {
    if(par[i] != 0){
        System.out.print(par[i] + " ");
    }
}

System.out.println("\nNúmeros Ímpares:");
for (int i = 0; i < impar.length; i++) {
    if(impar[i] != 0){
        System.out.print(impar[i] + " ");
    }
}
// Out:
// Números Pares:
// 6 4 6 12
// Números Ímpares:
// 9 9 15 13 17 15
// null

// %% [markdown]
// # Exercício 04
// <p style="text-align:justify;">
// Usando um array unidimensional de 10 elementos do tipo String, faça uma classe que simule a ocupação de um estacionamento de veículos. Considere que a posição do array corresponde ao número da vaga e para cada vaga é armazenada a placa do veículo que está estacionado. Sua classe deve conter um laço de repetição simulando um menu que controle a entrada e a saída dos veículos com as opções: 1-Entrada, 2-Saída e 3-Listar situação atual e 4-Encerrar o programa. Se o usuário escolher 1, solicite o número da vaga e a placa do veículo; se escolher 2, solicite o número da vaga que será liberada e armazene o valor branco na posição correspondente ao array; se escolher 3, liste a situação atual apresentando em tela todos os elementos do array; quando for 4, encerre o laço e o programa.
// </p>

// %%
import java.util.Scanner;
Scanner entrada = new Scanner(System.in);

String[] vagas = new String[10];
boolean executando = true;
int op;

while (executando) {
    System.out.println("Menu:");
    System.out.println("1 - Entrada de veículo");
    System.out.println("2 - Saída de veículo");
    System.out.println("3 - Listar situação atual");
    System.out.println("4 - Encerrar o programa");
    System.out.print("Escolha uma opção: ");

    op = entrada.nextInt();
    
    switch (op) {
        case 1:
            System.out.print("Número da vaga (0 a 9): ");
            int numVagaEntrada = entrada.nextInt();
            if (numVagaEntrada >= 0 && numVagaEntrada < 10) {
                System.out.print("Placa do veículo: ");
                String placa = entrada.next();
                vagas[numVagaEntrada] = placa;
                System.out.println("Veículo estacionado na vaga " + numVagaEntrada);
                System.out.println("Placa: " + vagas[numVagaEntrada]);
            } else {
                System.out.println("Vaga inválida. Digite um número entre 0 e 9.");
            }
            break;

        case 2:
            System.out.print("Número da vaga a ser liberada (0 a 9): ");
            int numVagaSaida = entrada.nextInt();
            if (numVagaSaida >= 0 && numVagaSaida < 10) {
                vagas[numVagaSaida] = "Vazia";
                System.out.println("Vaga " + numVagaSaida + " liberada.");
            } else {
                System.out.println("Vaga inválida. Digite um número entre 0 e 9.");
            }
            break;

        case 3:
            System.out.println("Situação atual do estacionamento:");
            for (int i = 0; i < 10; i++) {
                System.out.print(i + " ");
                if(vagas[i] != null){
                    System.out.println(vagas[i]);
                }else{
                    System.out.println("Vazia");
                }
            }
            break;

        case 4:
            System.out.println("Encerrando o programa...");
            executando = false;
            break;

        default:
            System.out.println("Opção inválida. Por favor, escolha uma opção válida.");
            break;
    }
}

entrada.close();
// Out:
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  5
// Opção inválida. Por favor, escolha uma opção válida.
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Número da vaga (0 a 9):
//  1
// Placa do veículo:
//  abc123
// Veículo estacionado na vaga 1
// Placa: abc123
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Número da vaga (0 a 9):
//  5
// Placa do veículo:
//  def456
// Veículo estacionado na vaga 5
// Placa: def456
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// 0 Vazia
// 1 abc123
// 2 Vazia
// 3 Vazia
// 4 Vazia
// 5 def456
// 6 Vazia
// 7 Vazia
// 8 Vazia
// 9 Vazia
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Número da vaga a ser liberada (0 a 9):
//  5
// Vaga 5 liberada.
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// 0 Vazia
// 1 abc123
// 2 Vazia
// 3 Vazia
// 4 Vazia
// 5 Vazia
// 6 Vazia
// 7 Vazia
// 8 Vazia
// 9 Vazia
// Menu:
// 1 - Entrada de veículo
// 2 - Saída de veículo
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  4
// Encerrando o programa...
// null

// %% [markdown]
// # Exercício 05
// <p style="text-align:justify;">
// Uma imagem é formada por pixels. Considere uma imagem com dimensão de 40 x 40 e faça uma classe que contenha um array bidimensional com essas dimensões. A seguir, para cada posição
// desse array bidimensional armazene um valor aleatório entre 0 e 255 (esses valores correspondem às tonalidades aplicadas sobre a imagem). Apresente em tela os 1600 valores gerados.
// </p>

// %%
import java.util.Random;

int[][] imagem = new int[40][40];
Random random = new Random();

for (int i = 0; i < 40; i++) {
    for (int j = 0; j < 40; j++) {
        int valor = random.nextInt(256); 
        imagem[i][j] = valor;
    }
}

for (int i = 0; i < 40; i++) {
    for (int j = 0; j < 40; j++) {
        System.out.print(imagem[i][j] + " ");
    }
    System.out.println();
}
// Out:
// 223 167 54 118 244 191 28 98 207 7 209 170 240 16 72 204 155 147 244 248 224 215 187 33 170 241 117 152 107 83 140 216 152 248 34 10 174 143 179 8
// 181 141 178 108 250 2 244 151 168 116 80 113 211 88 159 32 131 32 61 16 49 122 234 176 163 101 247 92 36 169 35 248 148 194 74 198 12 38 25 37
// 80 168 89 191 195 85 1 99 36 223 31 231 72 215 240 13 165 104 39 200 165 88 88 142 50 13 59 213 35 30 109 87 169 190 152 108 244 134 71 166
// 24 111 213 171 14 190 118 113 108 9 219 58 245 224 106 144 86 73 198 144 239 166 103 9 221 43 2 232 37 141 244 139 112 133 30 177 237 252 179 67
// 126 24 228 90 190 178 76 160 14 50 236 70 242 25 149 9 55 96 133 6 218 166 126 76 161 93 14 51 93 169 85 91 206 174 8 0 211 63 230 200
